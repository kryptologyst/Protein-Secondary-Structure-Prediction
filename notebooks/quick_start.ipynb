# %% [markdown]
# # Protein Secondary Structure Prediction - Quick Start
#
# This notebook demonstrates how to use the protein structure prediction system for research and educational purposes.
#
# **⚠️ DISCLAIMER: This is for research use only. Not for clinical or diagnostic use.**
